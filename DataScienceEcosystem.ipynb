# %% [markdown]
# # أدوات وبيئة علم البيانات

# %% [markdown]
# في هذا الدفتر، يتم تلخيص أدوات وبيئة علم البيانات.

# %% [markdown]
# بعض اللغات الشائعة التي يستخدمها علماء البيانات هي:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# بعض المكتبات الشائعة التي يستخدمها علماء البيانات تشمل:
# 1. Pandas
# 2. NumPy
# 3. Scikit-learn

# %% [markdown]
# | أدوات علم البيانات |
# |--------------------|
# | Jupyter Notebook  |
# | RStudio          |
# | Apache Spark     |

# %% [markdown]
# ### فيما يلي بعض الأمثلة على تقييم التعبيرات الحسابية في Python.

# %%
# هذا تعبير حسابي بسيط لضرب ثم إضافة الأعداد الصحيحة.
(3 * 4) + 5

# %%
# هذا سيحول 200 دقيقة إلى ساعات عن طريق القسمة على 60.
200 / 60

# %% [markdown]
# **الأهداف:**
# - قائمة اللغات الشائعة لعلم البيانات.
# - قائمة المكتبات الشائعة المستخدمة في علم البيانات.
# - عرض أدوات تحليل البيانات.
# - تقديم أمثلة على التعبيرات الحسابية في Python.

# %% [markdown]
# ## المؤلف
# اسمك هنا
